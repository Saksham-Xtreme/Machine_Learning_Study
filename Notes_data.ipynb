# %% [markdown]
# <a href="https://colab.research.google.com/github/Saksham-Xtreme/Machine_Learning_Study/blob/main/Notes_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # Types of Data

# ### 1. Numerical Data

# Numerical data is represented by numbers.

# **Types of Numerical Data:**

# * **Discrete Data:** Contains countable values.

#   * Example: Number of students, number of cars.
# * **Continuous Data:** Can contain any value within a range.

#   * Example: Height, weight, temperature.

# ### 2. Categorical Data

# Categorical data represents groups or categories.

# **Types of Categorical Data:**

# * **Nominal Data:** Categories without any specific order.

#   * Example: Gender, colors, city names.
# * **Ordinal Data:** Categories that have a meaningful order or ranking.

#   * Example: Low, Medium, High.

# ---

# # Pandas

# Pandas is used for **data manipulation and analysis** in Python.

# ### `pd.read_csv()`

# Used to **read/load a CSV file** into a Pandas DataFrame.

# ```python
# import pandas as pd

# data = pd.read_csv("file.csv")
# ```

# ---

# # Data Inspection Commands

# | Command           | Use                                           |
# | ----------------- | --------------------------------------------- |
# | `data.head()`     | Shows the first 5 rows                        |
# | `data.tail()`     | Shows the last 5 rows                         |
# | `data.shape`      | Shows `(rows, columns)`                       |
# | `data.info()`     | Gives dataset structure and data types        |
# | `data.describe()` | Gives a statistical summary of numerical data |

# ### Examples

# ```python
# data.head()
# data.tail()
# data.shape
# data.info()
# data.describe()
# ```

# ---

# # Univariate Analysis

# **Univariate analysis** means analyzing **one variable at a time**.

# Example:

# * Analyzing the distribution of students' marks.
# * Analyzing the age of people.
# * Analyzing the number of people in each category.

# ---

# # Box Plot

# A **box plot** is used to visualize the distribution of numerical data and **identify outliers**.

# It shows:

# * Minimum value
# * First Quartile (Q1)
# * Median (Q2)
# * Third Quartile (Q3)
# * Maximum value
# * **Outliers**

# Example:

# ```python
# import matplotlib.pyplot as plt

# plt.boxplot(data["Age"])
# plt.show()
# ```

# **Main use:** A box plot is commonly used to **detect outliers** in a dataset.

# Voilin plot data

# Violin Plot Data
# Violin, Line and Scatter Plot

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create data
data = pd.DataFrame({
    'categories': [
        'IT', 'IT', 'IT',
        'HR', 'HR', 'HR',
        'SALES', 'SALES', 'SALES',
        'Finance', 'Finance', 'Finance'
    ],

    'salary': [
        60000, 65000, 70000,
        45000, 48000, 52000,
        50000, 55000, 58000,
        65000, 70000, 75000
    ],

    'experience': [
        2, 4, 6,
        1, 3, 5,
        2, 4, 6,
        2, 4, 6
    ]
})

print(data)



# --------------------------------
# 1. VIOLIN PLOT
# --------------------------------

sns.violinplot(
    x='categories',
    y='salary',
    data=data
)

plt.title('Salary Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.show()


# --------------------------------
# 2. LINE PLOT
# --------------------------------

sns.lineplot(
    x='experience',
    y='salary',
    data=data,
    marker='o'
)

plt.title('Salary vs Experience')
plt.xlabel('Experience (Years)')
plt.ylabel('Salary')
plt.show()


# --------------------------------
# 1. SCATTER PLOT
# --------------------------------

sns.scatterplot(
    x='experience',
    y='salary',
    data=data,
    hue='categories',
    s=100
)

plt.title('Salary vs Experience')
plt.xlabel('Experience (Years)')
plt.ylabel('Salary')
plt.show()

#

plt.subplot(1,3,2)
avg_salary = df.groupby('categories')['salary'].mean()
avg_salary.plot(kind='bar')
plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
# Out:
#    categories  salary  experience
# 0          IT   60000           2
# 1          IT   65000           4
# 2          IT   70000           6
# 3          HR   45000           1
# 4          HR   48000           3
# 5          HR   52000           5
# 6       SALES   50000           2
# 7       SALES   55000           4
# 8       SALES   58000           6
# 9     Finance   65000           2
# 10    Finance   70000           4
# 11    Finance   75000           6

# %%
# student and marks

# student = a, b, c,d, a,b,c,d a,b,c,d
# marks = 70,80,90,100,68,78,69
